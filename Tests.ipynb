# %%
import numpy as np
from copy import deepcopy
from scipy import ndimage
import os
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd
from cont_extraction import binarize
from cont_extraction import get_outline_contour
from cont_extraction import load_resize_image

# %%
img = load_resize_image("C:\\Users\\arian\\Downloads\\unnamed.jpg")
mpx,mpy,finimg = binarize(img,white_or_black='black')

# %%
x,y = get_outline_contour(finimg,mpx,mpy)

# %%
fig,ax = plt.subplots()
ax.imshow(img)
ax.plot(x,y,'-r')
